# %%
name = "Sam"

# %%
name = "Pam"

# %%
print(name)
# Out:
# Pam

# %%
#  name[0]='S'

# %%
last_letters = name[1:]

# %%
new_name = 'S' + last_letters
print(name)
print(new_name)
# Out:
# Pam
# Sam

# %%
'Hello'
# Out:
# 'Hello'

# %%
'Hello' + new_name
# Out:
# 'HelloSam'

# %%
print(new_name * 10)
# Out:
# SamSamSamSamSamSamSamSamSamSam

# %%
print(5 + 4)
print("using 5 and 4 as str results in concat")
print('5' + '4')
# Out:
# 9
# using 5 and 4 as str results in concat
# 54

# %%
print(new_name.upper())
# Out:
# SAM

# %%
name.lower()
# Out:
# 'pam'

# %%
random_str = "My name is Anthony Con Service"

# %%
# by default i.e with no params, it splits by white spaces
# and returns a list object 
random_str.split()
# Out:
# ['My', 'name', 'is', 'Anthony', 'Con', 'Service']

# %%
random_str=random_str.split('i')

# %%
random_str
# Out:
# ['My name ', 's Anthony Con Serv', 'ce']

# %%
type(random_str)
# Out:
# list
