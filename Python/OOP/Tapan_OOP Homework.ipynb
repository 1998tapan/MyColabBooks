# %% [markdown]
# # Object Oriented Programming
# ## Homework Assignment
#
# #### Problem 1
# Fill in the Line class methods to accept coordinates as a pair of tuples and return the slope and distance of the line.

# %%
class Line:
    
    def __init__(self,coor1,coor2):
        self.coor1 = coor1
        self.coor2 = coor2
    
    def distance(self):
      #better approach
      #x1,y1 = self.coor1
      #x2,y2 = self.coor2
      #return ((x2-x1)**2 + (y2-y1)**2)**0.5

        x=abs(self.coor2[0]-self.coor1[0])**2
        y=abs(self.coor2[1]-self.coor1[1])**2
        return (x+y)**0.5
    
    def slope(self):
        y=self.coor2[1]-self.coor1[1]
        x=self.coor2[0]-self.coor1[0]
        return y/x

# %%
# EXAMPLE OUTPUT

coordinate1 = (3,2)
coordinate2 = (8,10)

li = Line(coordinate1,coordinate2)

# %%
li.distance()
# Out:
# 9.433981132056603

# %%
li.slope()
# Out:
# 1.6

# %% [markdown]
# ________
# #### Problem 2

# %% [markdown]
# Fill in the class

# %%
class Cylinder:
    
    def __init__(self,height=1,radius=1):
        self.height = height
        self.radius = radius
        
    def volume(self):
        return 3.14 * (self.radius**2) * self.height
    
    def surface_area(self):
        x=2 * 3.14 * self.radius * self.height
        y=2 * 3.14 * (self.radius **2)
        return x+y

# %%
# EXAMPLE OUTPUT
c = Cylinder(2,3)

# %%
c.volume()
# Out:
# 56.52

# %%
c.surface_area()
# Out:
# 94.2
