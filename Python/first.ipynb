# %%
a=5
a
# Out:
# 5

# %%
a=10

# %%
a
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
a=["Hello","World"]

# %%
type(a)
# Out:
# list

# %% [markdown]
# Python is dynamically typed - meaning you can re-assign values of different datatypes to a single variable.
#
# Java, C, C++ are statically typed.
#
# Dynamic Typing is a double edged sword.
# Always check the type of variable using Python's in-built function type(varName).
