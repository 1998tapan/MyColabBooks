# %%
import datetime

# %% [markdown]
# #Time

# %%
t = datetime.time(10,30,5)

# %%
print(t)
# Out:
# 10:30:05

# %%
print(t.hour)
print(t.minute)
print(t.second)
print(t.microsecond)
# Out:
# 10
# 30
# 5
# 0

# %%
t
# Out:
# datetime.time(10, 30, 5)

# %%
print(datetime.time.min)
# Out:
# 00:00:00

# %%
print(datetime.time.max)
# Out:
# 23:59:59.999999

# %%
print(datetime.time.resolution)
# Out:
# 0:00:00.000001

# %%
t1 = datetime.time(6,20,10)

# %%
print(t1)
# Out:
# 06:20:10

# %%
t2 = t1.replace(hour=9)

# %%
print(t2)
# Out:
# 09:20:10

# %% [markdown]
# #Datetime

# %%
current = datetime.datetime.now()

# %%
print(current)
# Out:
# 2020-02-29 07:28:01.310084

# %%
dt = current.replace(hour = 20)

# %%
print(dt)
# Out:
# 2020-02-29 20:28:01.310084

# %%
print(dt-current)
# Out:
# 13:00:00

# %%
print(current.now())
# Out:
# 2020-02-29 07:35:16.470188

# %%
print(current)
# Out:
# 2020-02-29 07:28:01.310084

# %%
print(current.tzinfo)
# Out:
# None

# %% [markdown]
# #Date

# %%
date = datetime.date.today()

# %%
print(date)
# Out:
# 2020-02-29

# %%
d1 = datetime.date(2012,12,21)

# %%
print(d1)
# Out:
# 2012-12-21

# %%
print(date-d1)
# Out:
# 2626 days, 0:00:00

# %%
print(date.timetuple())
# Out:
# time.struct_time(tm_year=2020, tm_mon=2, tm_mday=29, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=5, tm_yday=60, tm_isdst=-1)

# %%
print(date.year)
print(date.month)
print(date.day)
# Out:
# 2020
# 2
# 29

# %%
print(datetime.date.min)
print(datetime.date.max)
# Out:
# 0001-01-01
# 9999-12-31
