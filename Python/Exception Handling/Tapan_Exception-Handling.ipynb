# %%
try:
  f0=open('apple.txt',r)
  fo.write("Hello")
except:
  print("An error occured while writing to file")
# Out:
# An error occured while writing to file

# %%
try:
  fo=open('apple.txt','r')
  fo.write("Hello")
except IOError:
  print("An error occured while writing to file")
except:
  print("An error occured")
# Out:
# An error occured while writing to file

# %%
try:
  fo=open('apple.txt','w+')
  fo.write("Hello")
except IOError:
  print("An error occured while writing to file")
except:
  print("An error occured")
else:
  print("File written successfully")
# Out:
# File written successfully

# %%
try:
  fo=open('apple.txt','w+')
  fo.write("Hello")
except IOError:
  print("An error occured while writing to file")
else:
  print("File written successfully")
finally:
  print("I will always execute")
# Out:
# File written successfully
# I will always execute

# %%
try:
  fo=open('apple.txt','r')
  fo.write("Hello")
except IOError:
  print("An error occured while writing to file")
else:
  print("File written successfully")
finally:
  print("I will always execute")
# Out:
# An error occured while writing to file
# I will always execute

# %%
def read():
  while True:
    try:
      i = int(input("Enter an integer"))
    except:
      print("Enter an integer")
    else:
      print("Success !")
      #break, continue statements are hold till finally is executed
      break
    finally:
      print("I will always execute.")
    #this will never execute
    print(i)

# %%
read()
# Out:
# Enter an integer5
# Success !
# I will always execute.

# %%
read()
# Out:
# Enter an integerhi
# Enter an integer
# I will always execute.
# Enter an integerwew
# Enter an integer
# I will always execute.
# Enter an integer2
# Success !
# I will always execute.

# %%
def read():
  while True:
    try:
      i = int(input("Enter an integer"))
    except:
      print("Enter an integer")
    else:
      #this will now execute
      print(i)
      print("Success !")
      #break, continue statements are hold till finally is executed
      break
    finally:
      print("I will always execute.")

# %%
read()
# Out:
# Enter an integer3
# 3
# Success !
# I will always execute.
