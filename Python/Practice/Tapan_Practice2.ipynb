# %%
def evenNum(num = 2):
  num+=2
  return num

# %%
print(evenNum())
# Out:
# 4

# %%
def printEven(d={"one":2}):
  d["one"]+=2
  return d["one"]

# %%
print(printEven())
# Out:
# 4

# %%
print("Hello Skyrim")
# Out:
# Hello Skyrim

# %%
num = 123.232323

print(f'the num is {num:3.2f}')
# Out:
# the num is 123.23

# %%
li = [(1,2),(3,4),(5,6)]

for i in li:
  print(i)


for (a,b) in li:
  print(a,"\n",b)
# Out:
# (1, 2)
# (3, 4)
# (5, 6)
# 1
#  2
# 3
#  4
# 5
#  6

# %% [markdown]
# *dic* = {1:"one",2:"two",3:"three"}
#
# for {a:b} in dic:
#   print(a,":",b)

# %%
dic =
