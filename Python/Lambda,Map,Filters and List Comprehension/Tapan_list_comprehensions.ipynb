# %%
i = "I love jelly"
li = [letter for letter in i]

# %%
li
# Out:
# ['I', ' ', 'l', 'o', 'v', 'e', ' ', 'j', 'e', 'l', 'l', 'y']

# %%
li = [x for x in range(1,10)]

# %%
li
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
li = [x**2 for x in range (0,10)]

# %%
li
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
li = [x for x in range(1,10) if x%2==0]

# %%
li
# Out:
# [2, 4, 6, 8]

# %%
#nested
li = [x**2 for x in [x**2 for x in range(1,10)]]
li
# Out:
# [1, 16, 81, 256, 625, 1296, 2401, 4096, 6561]

# %%
#if else
li = [x if x%2 == 0 else "ODD" for x in range(1,10)]
li
# Out:
# ['ODD', 2, 'ODD', 4, 'ODD', 6, 'ODD', 8, 'ODD']

# %%
#celcius to fahrenheit
celcius = [0,20,33.2,37.6,43.5]
fahrenheit = [((9/5)*c+32) for c in celcius]
fahrenheit
# Out:
# [32.0, 68.0, 91.76, 99.68, 110.3]
